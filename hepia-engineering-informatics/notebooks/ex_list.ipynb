# %% [markdown]
# # Exercice : Analyse des données de résistance du béton avec des listes

# %% [markdown]
# ### Lecture des données
#
# Le cellule suivante lit les données de résistance du béton et les stocke dans une liste de listes. Chaque sous-liste contient les données d'une ligne du fichier.

# %%
file_path = "./resources/Concrete_Data_Yeh/Concrete_Data_Yeh.csv"

# lecture du fichier
with open(file_path, 'r') as file:
    list_tableau = []
    for line_id, line_content in enumerate(file):
        if line_id > 0:
            elements = line_content.strip().split(',')
            list_tableau.append(elements)
list_tableau
# Out:
# [['540', '0', '0', '162', '2.5', '1040', '676', '28', '79.99'],
#  ['540', '0', '0', '162', '2.5', '1055', '676', '28', '61.89'],
#  ['332.5', '142.5', '0', '228', '0', '932', '594', '270', '40.27'],
#  ['332.5', '142.5', '0', '228', '0', '932', '594', '365', '41.05'],
#  ['198.6', '132.4', '0', '192', '0', '978.4', '825.5', '360', '44.3'],
#  ['266', '114', '0', '228', '0', '932', '670', '90', '47.03'],
#  ['380', '95', '0', '228', '0', '932', '594', '365', '43.7'],
#  ['380', '95', '0', '228', '0', '932', '594', '28', '36.45'],
#  ['266', '114', '0', '228', '0', '932', '670', '28', '45.85'],
#  ['475', '0', '0', '228', '0', '932', '594', '28', '39.29'],
#  ['198.6', '132.4', '0', '192', '0', '978.4', '825.5', '90', '38.07'],
#  ['198.6', '132.4', '0', '192', '0', '978.4', '825.5', '28', '28.02'],
#  ['427.5', '47.5', '0', '228', '0', '932', '594', '270', '43.01'],
#  ['190', '190', '0', '228', '0', '932', '670', '90', '42.33'],
# ...

# %% [markdown]
# ### Compter le nombre de lignes dans le fichier

# %%
# todo

# %% [markdown]
# ### Compter les nombres d'élément par ligne dans le fichier.

# %%
# todo

# %% [markdown]
# ### Afficher uniquement les 3 premières lignes du fichier.

# %%
# todo

# %% [markdown]
# ### Afficher uniquement les 3 dernières lignes du fichier.

# %%
# todo

# %% [markdown]
# ### Afficher uniquement que les lignes impaires du fichier.

# %%
## todo

# %% [markdown]
# ### Sélection d'un élément dans la liste
#
# Selectionner la contenu en eau (en g par m3 de mélange) pour un ciment de 427.5 kg par m3 de mélange

# %%
# todo

# %% [markdown]
# ### Nouvelle liste
#
# Créer une nouvelle list "new_list" avec uniquement que la moitié des lignes du tableau

# %%
# todo

# %% [markdown]
# Créer une nouvelle "new_list_inverse" avec les lignes dans l'ordre inverse

# %%
# todo
